# %% [markdown]
# <a href="https://colab.research.google.com/github/tanvikurundkar/Pneumonia-Detection/blob/main/Tanvi_PneumoniaDetection_Section3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color="#de3023"><h1><b>REMINDER MAKE A COPY OF THIS NOTEBOOK, DO NOT EDIT</b></h1></font>

# %% [markdown]
# ![](https://storage.googleapis.com/kaggle-competitions/kaggle/10338/logos/header.png)

# %% [markdown]
# In this notebook, we'll try out our model on field data - data outside our normal testing and training data! We'll also learn techniques for data augmentation, creating new "fake data" so that our model can generalize more effectively.

# %% [markdown]
# In this notebook we'll be:
# 1.   Putting our ML models into practice
# 2.   Improving our ML models

# %%
#@title Run this to download data and prepare our environment! { display-mode: "form" }
# %tensorflow_version 1.x
import random

import gdown
import zipfile

import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, confusion_matrix

import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, GlobalAveragePooling2D
from keras.regularizers import l2
from keras.wrappers.scikit_learn import KerasClassifier
import tensorflow.keras.optimizers as optimizers
from keras.callbacks import ModelCheckpoint

from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet50 import ResNet50
from keras.applications.densenet import DenseNet121

from imgaug import augmenters 
def augment(data, augmenter):
  if len(data.shape) == 3:
    return augmenter.augment_image(data)
  if len(data.shape) == 4:
    return augmenter.augment_images(data)
    
def rotate(data, rotate):
  fun = augmenters.Affine(rotate = rotate)
  return augment(data, fun)

def shear(data, shear):
  fun = augmenters.Affine(shear = shear)
  return augment(data, fun)

def scale(data, scale):
  fun = augmenters.Affine(scale = scale)
  return augment(data, fun)
  
def flip_left_right(data, prob):
  fun = augmenters.Fliplr(p = prob)
  return augment(data, fun)

def flip_up_down(data, prob):
  fun = augmenters.Flipud(p = prob)
  return augment(data, fun)

def remove_color(data, channel):
  new_data = data.copy()
  if len(data.shape) == 3:
    new_data[:,:,channel] = 0
    return new_data
  if len(data.shape) == 4:
    new_data[:,:,:,channel] = 0
    return new_data
  
class pkg:
  #### DOWNLOADING AND LOADING DATA
  def get_metadata(metadata_path, which_splits = ['train', 'test']):  
    '''returns metadata dataframe which contains columns of:
       * index: index of data into numpy data
       * class: class of image
       * split: which dataset split is this a part of? 
    '''
    metadata = pd.read_csv(metadata_path)
    keep_idx = metadata['split'].isin(which_splits)
    return metadata[keep_idx]

  def get_data_split(split_name, flatten, all_data, metadata, image_shape):
    '''
    returns images (data), labels from folder of format [image_folder]/[split_name]/[class_name]/
    flattens if flatten option is True 
    '''
    sub_df = metadata[metadata['split'].isin([split_name])]
    index  = sub_df['index'].values
    labels = sub_df['class'].values
    data = all_data[index,:]
    if flatten:
      data = data.reshape([-1, np.product(image_shape)])
    return data, labels

  def get_train_data(flatten, all_data, metadata, image_shape):
    return get_data_split('train', flatten, all_data, metadata, image_shape)

  def get_test_data(flatten, all_data, metadata, image_shape):
    return get_data_split('test', flatten, all_data, metadata, image_shape)

  def get_field_data(flatten, all_data, metadata, image_shape):
    field_data, field_labels = get_data_split('field', flatten, all_data, metadata, image_shape)
    field_data[:,:,:,2] = field_data[:,:,:,0]
    field_data[:,:,:,1] = field_data[:,:,:,0]

    #make data messier
    rand = random.uniform(-1, 1)
    
    for i in range(len(field_data)):
      image = field_data[i]
                            
      if abs(rand) < 0.5:
        image = rotate(image, rotate = rand * 40)
      elif abs(rand) < 0.8:
        image = shear(image, shear = rand*40)
      field_data[i] = image 
    return field_data, field_labels

class helpers:
  #### PLOTTING
  def plot_one_image(data, labels = [], index = None, image_shape = [64,64,3]):
    '''
    if data is a single image, display that image

    if data is a 4d stack of images, display that image
    '''
    num_dims   = len(data.shape)
    num_labels = len(labels)

    # reshape data if necessary
    if num_dims == 1:
      data = data.reshape(target_shape)
    if num_dims == 2:
      data = data.reshape(np.vstack[-1, image_shape])
    num_dims   = len(data.shape)

    # check if single or multiple images
    if num_dims == 3:
      if num_labels > 1:
        print('Multiple labels does not make sense for single image.')
        return

      label = labels      
      if num_labels == 0:
        label = ''
      image = data

    if num_dims == 4:
      image = data[index, :]
      label = labels[index]

    # plot image of interest
    print('Label: %s'%label)
    plt.imshow(image)
    plt.show()

  #### QUERYING AND COMBINING DATA
  def get_misclassified_data(data, labels, predictions):
    '''
    Gets the data and labels that are misclassified in a classification task
    Returns:
    -missed_data
    -missed_labels
    -predicted_labels (corresponding to missed_labels)
    -missed_index (indices of items in original dataset)
    '''
    missed_index     = np.where(np.abs(predictions.squeeze() - labels.squeeze()) > 0)[0]
    missed_labels    = labels[missed_index]
    missed_data      = data[missed_index,:]
    predicted_labels = predictions[missed_index]
    return missed_data, missed_labels, predicted_labels, missed_index

  def combine_data(data_list, labels_list):
    return np.concatenate(data_list, axis = 0), np.concatenate(labels_list, axis = 0)

  def plot_acc(history, ax = None, xlabel = 'Epoch #'):
    # i'm sorry for this function's code. i am so sorry. 
    history = history.history
    history.update({'epoch':list(range(len(history['val_accuracy'])))})
    history = pd.DataFrame.from_dict(history)

    best_epoch = history.sort_values(by = 'val_accuracy', ascending = False).iloc[0]['epoch']

    if not ax:
      f, ax = plt.subplots(1,1)
    sns.lineplot(x = 'epoch', y = 'val_accuracy', data = history, label = 'Validation', ax = ax)
    sns.lineplot(x = 'epoch', y = 'accuracy', data = history, label = 'Training', ax = ax)
    ax.axhline(0.5, linestyle = '--',color='red', label = 'Chance')
    ax.axvline(x = best_epoch, linestyle = '--', color = 'green', label = 'Best Epoch')  
    ax.legend(loc = 4)    
    ax.set_ylim([0.4, 1])

    ax.set_xlabel(xlabel)
    ax.set_ylabel('Accuracy (Fraction)')
    
    plt.show()

class models:
  def DenseClassifier(hidden_layer_sizes, nn_params):
    model = Sequential()
    model.add(Flatten(input_shape = nn_params['input_shape']))
    model.add(Dropout(0.5))

    for ilayer in hidden_layer_sizes:
      model.add(Dense(ilayer, activation = 'relu'))
      model.add(Dropout(0.5))
    
    model.add(Dense(units = nn_params['output_neurons'], activation = nn_params['output_activation']))
    model.compile(loss=nn_params['loss'],
                  optimizer=keras.optimizers.SGD(learning_rate=1e-4, momentum=0.95),
                  metrics=['accuracy'])
    return model

  def CNNClassifier(num_hidden_layers, nn_params):
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=nn_params['input_shape'], padding = 'same', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    for i in range(num_hidden_layers-1):
        model.add(Conv2D(64, (3, 3), padding = 'same', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten()) 

    model.add(Dense(units = 128, activation = 'relu'))
    model.add(Dropout(0.5))
    model.add(Dense(units = 64, activation = 'relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
    model.add(Dropout(0.5))

    model.add(Dense(units = nn_params['output_neurons'], activation = nn_params['output_activation']))

    # initiate RMSprop optimizer
    opt = keras.optimizers.RMSprop(learning_rate=1e-5, decay=1e-6)

    # Let's train the model using RMSprop
    model.compile(loss=nn_params['loss'],
                  optimizer=opt,
                  metrics=['accuracy'])    
    return model

  def TransferClassifier(name, nn_params, trainable = True):
    expert_dict = {'VGG16': VGG16, 
                   'VGG19': VGG19,
                   'ResNet50':ResNet50,
                   'DenseNet121':DenseNet121}

    expert_conv = expert_dict[name](weights = 'imagenet', 
                                              include_top = False, 
                                              input_shape = nn_params['input_shape'])
    for layer in expert_conv.layers:
      layer.trainable = trainable
      
    expert_model = Sequential()
    expert_model.add(expert_conv)
    expert_model.add(GlobalAveragePooling2D())

    expert_model.add(Dense(128, activation = 'relu'))
    expert_model.add(Dropout(0.5))

    expert_model.add(Dense(64, activation = 'relu'))
    expert_model.add(Dropout(0.5))

    expert_model.add(Dense(nn_params['output_neurons'], activation = nn_params['output_activation']))

    expert_model.compile(loss = nn_params['loss'], 
                  optimizer = keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9), 
                  metrics=['accuracy'])

    return expert_model

### defining project variables
# file variables
metadata_url         = "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/metadata.csv"
image_data_url       = 'https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/image_data.npy'
image_data_path      = './image_data.npy'
metadata_path        = './metadata.csv'
image_shape          = (64, 64, 3)

# neural net parameters
nn_params = {}
nn_params['input_shape']       = image_shape
nn_params['output_neurons']    = 1
nn_params['loss']              = 'binary_crossentropy'
nn_params['output_activation'] = 'sigmoid'

###
# gdown.download(image_data_url, './image_data.npy', True)
# gdown.download(metadata_url, './metadata.csv', True)
# !wget "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/metadata.csv"
# !wget "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/image_data.npy"


### pre-loading all data of interest
_all_data = np.load('image_data.npy')
_metadata = pkg.get_metadata(metadata_path, ['train','test','field'])

### preparing definitions
# downloading and loading data
get_data_split = pkg.get_data_split
get_metadata    = lambda :                 pkg.get_metadata(metadata_path, ['train','test'])
get_train_data  = lambda flatten = False : pkg.get_train_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)
get_test_data   = lambda flatten = False : pkg.get_test_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)
get_field_data  = lambda flatten = False : pkg.get_field_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)

# plotting
plot_one_image = lambda data, labels = [], index = None: helpers.plot_one_image(data = data, labels = labels, index = index, image_shape = image_shape);
plot_acc       = lambda history: helpers.plot_acc(history)

# querying and combining data
get_misclassified_data = helpers.get_misclassified_data;
combine_data           = helpers.combine_data;

# models with input parameters
DenseClassifier     = lambda hidden_layer_sizes: models.DenseClassifier(hidden_layer_sizes = hidden_layer_sizes, nn_params = nn_params);
CNNClassifier       = lambda num_hidden_layers: models.CNNClassifier(num_hidden_layers, nn_params = nn_params);
TransferClassifier  = lambda name: models.TransferClassifier(name = name, nn_params = nn_params);

monitor = ModelCheckpoint('./model.h5', monitor='val_accuracy', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
# Out:
# --2022-07-01 02:50:21--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/metadata.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.212.128, 173.194.215.128, 173.194.216.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.212.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 40508 (40K) [text/csv]
# Saving to: ‘metadata.csv’
#
# metadata.csv        100%[===================>]  39.56K  --.-KB/s    in 0.001s
#
# 2022-07-01 02:50:21 (50.4 MB/s) - ‘metadata.csv’ saved [40508/40508]
#
# --2022-07-01 02:50:21--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20(Healthcare%20A)%20Pneumonia/image_data.npy
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.196.128, 74.125.139.128, 74.125.141.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.196.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 137625728 (131M) [application/octet-stream]
# Saving to: ‘image_data.npy’
#
# image_data.npy      100%[===================>] 131.25M   185MB/s    in 0.7s
#
# 2022-07-01 02:50:22 (185 MB/s) - ‘image_data.npy’ saved [137625728/137625728]

# %% [markdown]
# # Milestone 1: Putting our model into practice

# %% [markdown]
# ## Activity 1a: Testing on Field Data
# #### While your models may have done well on your original training and validation data, deploying the model on "field" data can present different challenges. Field data is data that is different from the one where you built your model. For e.g. images obtained from a different x-ray machine.

# %% [markdown]
# ### Exercise (Coding)

# %% [markdown]
# Yesterday we worked with CNNs, which we saw perform much better than multi-layer perceptrons on imaging data.
#
# Below, please **re-train a 2-layer CNN and plot its accuracy over time!** (You can use all the functions from yesterday's code.) You can choose the number of epochs based on the graph.

# %%
train_data, train_labels = get_train_data()
test_data, test_labels   = get_test_data()

### YOUR CODE HERE
cnn = CNNClassifier(num_hidden_layers = 2)
model_history_cnn = cnn.fit(train_data, train_labels, epochs = 50, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
plot_acc(model_history_cnn)
### END CODE
# Out:
# Epoch 1/50
# 63/63 [==============================] - 2s 12ms/step - loss: 2.0214 - accuracy: 0.5340 - val_loss: 2.0058 - val_accuracy: 0.6900
# Epoch 2/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9937 - accuracy: 0.5855 - val_loss: 1.9817 - val_accuracy: 0.6975
# Epoch 3/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9693 - accuracy: 0.6215 - val_loss: 1.9529 - val_accuracy: 0.8025
# Epoch 4/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9360 - accuracy: 0.6740 - val_loss: 1.9236 - val_accuracy: 0.8325
# Epoch 5/50
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9037 - accuracy: 0.7120 - val_loss: 1.8933 - val_accuracy: 0.8475
# Epoch 6/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8727 - accuracy: 0.7375 - val_loss: 1.8630 - val_accuracy: 0.8450
# Epoch 7/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8468 - accuracy: 0.7355 - val_loss: 1.8387 - val_accuracy: 0.8100
# Epoch 8/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8129 - accuracy: 0.7630 - val_loss: 1.8048 - val_accuracy: 0.8525
# Epoch 9/50
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7880 - accuracy: 0.7870 - val_loss: 1.7781 - val_accuracy: 0.8225
# Epoch 10/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7527 - accuracy: 0.8065 - val_loss: 1.7528 - val_accuracy: 0.8175
# Epoch 11/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7231 - accuracy: 0.8055 - val_loss: 1.7201 - val_accuracy: 0.8625
# Epoch 12/50
# 63/63 [==============================] - 1s 10ms/step - loss: 1.6932 - accuracy: 0.8195 - val_loss: 1.7010 - val_accuracy: 0.8075
# Epoch 13/50
# 63/63 [==============================] - 1s 11ms/step - loss: 1.6630 - accuracy: 0.8175 - val_loss: 1.6658 - val_accuracy: 0.8450
# Epoch 14/50
# 63/63 [==============================] - 1s 13ms/step - loss: 1.6349 - accuracy: 0.8295 - val_loss: 1.6646 - val_accuracy: 0.7800
# Epoch 15/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.6182 - accuracy: 0.8260 - val_loss: 1.6209 - val_accuracy: 0.8350
# Epoch 16/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.5908 - accuracy: 0.8470 - val_loss: 1.5995 - val_accuracy: 0.8350
# Epoch 17/50
# 63/63 [==============================] - 1s 14ms/step - loss: 1.5724 - accuracy: 0.8470 - val_loss: 1.5850 - val_accuracy: 0.8375
# Epoch 18/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.5413 - accuracy: 0.8570 - val_loss: 1.5533 - val_accuracy: 0.8475
# Epoch 19/50
# 63/63 [==============================] - 1s 13ms/step - loss: 1.5191 - accuracy: 0.8575 - val_loss: 1.5294 - val_accuracy: 0.8600
# Epoch 20/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.4882 - accuracy: 0.8705 - val_loss: 1.5433 - val_accuracy: 0.8000
# Epoch 21/50
# 63/63 [==============================] - 1s 13ms/step - loss: 1.4791 - accuracy: 0.8565 - val_loss: 1.5286 - val_accuracy: 0.8000
# Epoch 22/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.4587 - accuracy: 0.8755 - val_loss: 1.5044 - val_accuracy: 0.8125
# Epoch 23/50
# 63/63 [==============================] - 1s 14ms/step - loss: 1.4368 - accuracy: 0.8715 - val_loss: 1.4870 - val_accuracy: 0.8150
# Epoch 24/50
# 63/63 [==============================] - 1s 11ms/step - loss: 1.4146 - accuracy: 0.8735 - val_loss: 1.4860 - val_accuracy: 0.7950
# Epoch 25/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.3962 - accuracy: 0.8820 - val_loss: 1.4215 - val_accuracy: 0.8725
# Epoch 26/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.3740 - accuracy: 0.8885 - val_loss: 1.4111 - val_accuracy: 0.8675
# Epoch 27/50
# 63/63 [==============================] - 1s 11ms/step - loss: 1.3613 - accuracy: 0.8845 - val_loss: 1.3880 - val_accuracy: 0.8800
# Epoch 28/50
# 63/63 [==============================] - 1s 13ms/step - loss: 1.3335 - accuracy: 0.9075 - val_loss: 1.4059 - val_accuracy: 0.8250
# Epoch 29/50
# 63/63 [==============================] - 1s 13ms/step - loss: 1.3349 - accuracy: 0.8820 - val_loss: 1.3492 - val_accuracy: 0.8775
# Epoch 30/50
# 63/63 [==============================] - 1s 14ms/step - loss: 1.3095 - accuracy: 0.9010 - val_loss: 1.3731 - val_accuracy: 0.8400
# Epoch 31/50
# 63/63 [==============================] - 1s 15ms/step - loss: 1.2934 - accuracy: 0.9015 - val_loss: 1.3928 - val_accuracy: 0.8200
# Epoch 32/50
# 63/63 [==============================] - 1s 15ms/step - loss: 1.2832 - accuracy: 0.9055 - val_loss: 1.3463 - val_accuracy: 0.8525
# Epoch 33/50
# 63/63 [==============================] - 1s 17ms/step - loss: 1.2659 - accuracy: 0.9025 - val_loss: 1.3098 - val_accuracy: 0.8850
# Epoch 34/50
# 63/63 [==============================] - 1s 16ms/step - loss: 1.2543 - accuracy: 0.8995 - val_loss: 1.3601 - val_accuracy: 0.8175
# Epoch 35/50
# 63/63 [==============================] - 1s 19ms/step - loss: 1.2317 - accuracy: 0.9105 - val_loss: 1.2822 - val_accuracy: 0.8900
# Epoch 36/50
# 63/63 [==============================] - 1s 13ms/step - loss: 1.2167 - accuracy: 0.9150 - val_loss: 1.3638 - val_accuracy: 0.7825
# Epoch 37/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.2012 - accuracy: 0.9120 - val_loss: 1.2669 - val_accuracy: 0.8825
# Epoch 38/50
# 63/63 [==============================] - 1s 13ms/step - loss: 1.1869 - accuracy: 0.9155 - val_loss: 1.2555 - val_accuracy: 0.8825
# Epoch 39/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.1771 - accuracy: 0.9120 - val_loss: 1.2491 - val_accuracy: 0.8800
# Epoch 40/50
# 63/63 [==============================] - 1s 11ms/step - loss: 1.1676 - accuracy: 0.9135 - val_loss: 1.2739 - val_accuracy: 0.8475
# Epoch 41/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.1552 - accuracy: 0.9140 - val_loss: 1.2887 - val_accuracy: 0.8225
# Epoch 42/50
# 63/63 [==============================] - 1s 13ms/step - loss: 1.1338 - accuracy: 0.9235 - val_loss: 1.2360 - val_accuracy: 0.8625
# Epoch 43/50
# 63/63 [==============================] - 1s 12ms/step - loss: 1.1209 - accuracy: 0.9280 - val_loss: 1.2217 - val_accuracy: 0.8675
# Epoch 44/50
# 63/63 [==============================] - 1s 11ms/step - loss: 1.1108 - accuracy: 0.9325 - val_loss: 1.2603 - val_accuracy: 0.8175
# Epoch 45/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0914 - accuracy: 0.9260 - val_loss: 1.2385 - val_accuracy: 0.8375
# Epoch 46/50
# 63/63 [==============================] - 1s 8ms/step - loss: 1.0883 - accuracy: 0.9305 - val_loss: 1.2385 - val_accuracy: 0.8275
# Epoch 47/50
# 63/63 [==============================] - 1s 8ms/step - loss: 1.0729 - accuracy: 0.9335 - val_loss: 1.1764 - val_accuracy: 0.8775
# Epoch 48/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0774 - accuracy: 0.9220 - val_loss: 1.1660 - val_accuracy: 0.8800
# Epoch 49/50
# 63/63 [==============================] - 1s 8ms/step - loss: 1.0584 - accuracy: 0.9280 - val_loss: 1.1808 - val_accuracy: 0.8500
# Epoch 50/50
# 63/63 [==============================] - 1s 9ms/step - loss: 1.0491 - accuracy: 0.9320 - val_loss: 1.2328 - val_accuracy: 0.8125

# %% [markdown]
# ### Exercise (Coding)

# %% [markdown]
# Our radiologist friends have provided us with some new data from the field. We can access this with `get_field_data()`.
#
# Please create **field_data** and **field_labels**.

# %%
#YOUR CODE HERE
field_data, field_labels=get_field_data()

# %% [markdown]
# What accuracy do you get when you use your trained CNN on the field data? Please calculate it below (hint: `(predict() > 0.5).astype("int32")`.)

# %%
#YOUR CODE HERE
predictions=(cnn.predict(field_data)>0.5).astype('int32')
accuracy=accuracy_score(field_labels,predictions)
print(accuracy)
# Out:
# 0.53

# %% [markdown]
# **Discuss:** How does your performance on field data compare to test and train data?
#
# You've probably noticed that you get different performance every time you train your model! Let's get a sense of the average: below, please **train your model 5 times, calculate the accuracy on the field data each time, and print the average accuracy.**

# %%
### YOUR CODE HERE
train_data, train_labels = get_train_data()
test_data, test_labels   = get_test_data()
field_data, field_labels=get_field_data()
sum=0.0

for i in range(5):
  cnn = CNNClassifier(num_hidden_layers = 2)
  model_history_cnn = cnn.fit(train_data, train_labels, epochs = 25, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
  plot_acc(model_history_cnn)
  predictions=(cnn.predict(field_data)>0.5).astype('int32')
  accuracy=accuracy_score(field_labels,predictions)
  sum+=accuracy
print(sum/5)
### END CODE
# Out:
# Epoch 1/25
# 63/63 [==============================] - 2s 13ms/step - loss: 2.0166 - accuracy: 0.5410 - val_loss: 1.9974 - val_accuracy: 0.7625
# Epoch 2/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9813 - accuracy: 0.6275 - val_loss: 1.9638 - val_accuracy: 0.7800
# Epoch 3/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9431 - accuracy: 0.6770 - val_loss: 1.9267 - val_accuracy: 0.7875
# Epoch 4/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9057 - accuracy: 0.7280 - val_loss: 1.8942 - val_accuracy: 0.7825
# Epoch 5/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8674 - accuracy: 0.7575 - val_loss: 1.8675 - val_accuracy: 0.7500
# Epoch 6/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8340 - accuracy: 0.7805 - val_loss: 1.8377 - val_accuracy: 0.7575
# Epoch 7/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7988 - accuracy: 0.8100 - val_loss: 1.7989 - val_accuracy: 0.7950
# Epoch 8/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7605 - accuracy: 0.8155 - val_loss: 1.7736 - val_accuracy: 0.7850
# Epoch 9/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7325 - accuracy: 0.8260 - val_loss: 1.7384 - val_accuracy: 0.8050
# Epoch 10/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7057 - accuracy: 0.8290 - val_loss: 1.7223 - val_accuracy: 0.7825
# Epoch 11/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6726 - accuracy: 0.8400 - val_loss: 1.6843 - val_accuracy: 0.8150
# Epoch 12/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.6505 - accuracy: 0.8510 - val_loss: 1.6661 - val_accuracy: 0.8125
# Epoch 13/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6302 - accuracy: 0.8485 - val_loss: 1.6590 - val_accuracy: 0.7850
# Epoch 14/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.5900 - accuracy: 0.8635 - val_loss: 1.6291 - val_accuracy: 0.8025
# Epoch 15/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.5789 - accuracy: 0.8680 - val_loss: 1.6384 - val_accuracy: 0.7725
# Epoch 16/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.5475 - accuracy: 0.8745 - val_loss: 1.5624 - val_accuracy: 0.8550
# Epoch 17/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5245 - accuracy: 0.8820 - val_loss: 1.5782 - val_accuracy: 0.8100
# Epoch 18/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5035 - accuracy: 0.8910 - val_loss: 1.5428 - val_accuracy: 0.8400
# Epoch 19/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4763 - accuracy: 0.8900 - val_loss: 1.5055 - val_accuracy: 0.8575
# Epoch 20/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4686 - accuracy: 0.8890 - val_loss: 1.4942 - val_accuracy: 0.8625
# Epoch 21/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4469 - accuracy: 0.8915 - val_loss: 1.5177 - val_accuracy: 0.8250
# Epoch 22/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4216 - accuracy: 0.9065 - val_loss: 1.4718 - val_accuracy: 0.8650
# Epoch 23/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4148 - accuracy: 0.8990 - val_loss: 1.4883 - val_accuracy: 0.8275
# Epoch 24/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.3946 - accuracy: 0.9065 - val_loss: 1.4679 - val_accuracy: 0.8375
# Epoch 25/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.3761 - accuracy: 0.9045 - val_loss: 1.4109 - val_accuracy: 0.8700
# Epoch 1/25
# 63/63 [==============================] - 3s 16ms/step - loss: 2.0283 - accuracy: 0.5370 - val_loss: 2.0087 - val_accuracy: 0.5575
# Epoch 2/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9972 - accuracy: 0.6210 - val_loss: 1.9819 - val_accuracy: 0.7750
# Epoch 3/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9598 - accuracy: 0.6815 - val_loss: 1.9458 - val_accuracy: 0.7550
# Epoch 4/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9286 - accuracy: 0.6855 - val_loss: 1.9162 - val_accuracy: 0.8200
# Epoch 5/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8984 - accuracy: 0.7265 - val_loss: 1.8888 - val_accuracy: 0.7725
# Epoch 6/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8585 - accuracy: 0.7560 - val_loss: 1.8522 - val_accuracy: 0.8150
# Epoch 7/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.8277 - accuracy: 0.7785 - val_loss: 1.8314 - val_accuracy: 0.7600
# Epoch 8/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7923 - accuracy: 0.7955 - val_loss: 1.7846 - val_accuracy: 0.8425
# Epoch 9/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7559 - accuracy: 0.8165 - val_loss: 1.7730 - val_accuracy: 0.7725
# Epoch 10/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7284 - accuracy: 0.8115 - val_loss: 1.7337 - val_accuracy: 0.8275
# Epoch 11/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6977 - accuracy: 0.8220 - val_loss: 1.7102 - val_accuracy: 0.8050
# Epoch 12/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6666 - accuracy: 0.8390 - val_loss: 1.6748 - val_accuracy: 0.8450
# Epoch 13/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6395 - accuracy: 0.8430 - val_loss: 1.6594 - val_accuracy: 0.8150
# Epoch 14/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6104 - accuracy: 0.8615 - val_loss: 1.6227 - val_accuracy: 0.8500
# Epoch 15/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5909 - accuracy: 0.8610 - val_loss: 1.6183 - val_accuracy: 0.8125
# Epoch 16/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5653 - accuracy: 0.8640 - val_loss: 1.5918 - val_accuracy: 0.8250
# Epoch 17/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5353 - accuracy: 0.8795 - val_loss: 1.5563 - val_accuracy: 0.8500
# Epoch 18/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5201 - accuracy: 0.8720 - val_loss: 1.5336 - val_accuracy: 0.8525
# Epoch 19/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4939 - accuracy: 0.8780 - val_loss: 1.5159 - val_accuracy: 0.8500
# Epoch 20/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4642 - accuracy: 0.8870 - val_loss: 1.5198 - val_accuracy: 0.8400
# Epoch 21/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4662 - accuracy: 0.8760 - val_loss: 1.5386 - val_accuracy: 0.7875
# Epoch 22/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4305 - accuracy: 0.8970 - val_loss: 1.5193 - val_accuracy: 0.7975
# Epoch 23/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4166 - accuracy: 0.8975 - val_loss: 1.5168 - val_accuracy: 0.7875
# Epoch 24/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4010 - accuracy: 0.9010 - val_loss: 1.4577 - val_accuracy: 0.8475
# Epoch 25/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.3779 - accuracy: 0.9080 - val_loss: 1.4357 - val_accuracy: 0.8550
# Epoch 1/25
# 63/63 [==============================] - 2s 12ms/step - loss: 2.0127 - accuracy: 0.5220 - val_loss: 1.9935 - val_accuracy: 0.7000
# Epoch 2/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9872 - accuracy: 0.5685 - val_loss: 1.9656 - val_accuracy: 0.7950
# Epoch 3/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9556 - accuracy: 0.6245 - val_loss: 1.9369 - val_accuracy: 0.7700
# Epoch 4/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9268 - accuracy: 0.6740 - val_loss: 1.9092 - val_accuracy: 0.8475
# Epoch 5/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8959 - accuracy: 0.7000 - val_loss: 1.8877 - val_accuracy: 0.7600
# Epoch 6/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8614 - accuracy: 0.7440 - val_loss: 1.8466 - val_accuracy: 0.8350
# Epoch 7/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8339 - accuracy: 0.7630 - val_loss: 1.8252 - val_accuracy: 0.8300
# Epoch 8/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7974 - accuracy: 0.7830 - val_loss: 1.7923 - val_accuracy: 0.8500
# Epoch 9/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7758 - accuracy: 0.7915 - val_loss: 1.7699 - val_accuracy: 0.8150
# Epoch 10/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7344 - accuracy: 0.8010 - val_loss: 1.7309 - val_accuracy: 0.8500
# Epoch 11/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7131 - accuracy: 0.7950 - val_loss: 1.7018 - val_accuracy: 0.8650
# Epoch 12/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6802 - accuracy: 0.8140 - val_loss: 1.6864 - val_accuracy: 0.8475
# Epoch 13/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.6496 - accuracy: 0.8225 - val_loss: 1.6496 - val_accuracy: 0.8650
# Epoch 14/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6191 - accuracy: 0.8375 - val_loss: 1.6373 - val_accuracy: 0.8300
# Epoch 15/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.6021 - accuracy: 0.8295 - val_loss: 1.6101 - val_accuracy: 0.8500
# Epoch 16/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5747 - accuracy: 0.8420 - val_loss: 1.5928 - val_accuracy: 0.8375
# Epoch 17/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5454 - accuracy: 0.8535 - val_loss: 1.5754 - val_accuracy: 0.8250
# Epoch 18/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5229 - accuracy: 0.8655 - val_loss: 1.5468 - val_accuracy: 0.8550
# Epoch 19/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4989 - accuracy: 0.8580 - val_loss: 1.5070 - val_accuracy: 0.8650
# Epoch 20/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4809 - accuracy: 0.8705 - val_loss: 1.4915 - val_accuracy: 0.8650
# Epoch 21/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4623 - accuracy: 0.8760 - val_loss: 1.4909 - val_accuracy: 0.8575
# Epoch 22/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4289 - accuracy: 0.8815 - val_loss: 1.5039 - val_accuracy: 0.7950
# Epoch 23/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4192 - accuracy: 0.8760 - val_loss: 1.4458 - val_accuracy: 0.8750
# Epoch 24/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.3968 - accuracy: 0.8845 - val_loss: 1.4336 - val_accuracy: 0.8675
# Epoch 25/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.3773 - accuracy: 0.8940 - val_loss: 1.4151 - val_accuracy: 0.8700
# Epoch 1/25
# 63/63 [==============================] - 2s 13ms/step - loss: 2.0097 - accuracy: 0.5435 - val_loss: 1.9949 - val_accuracy: 0.7350
# Epoch 2/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9804 - accuracy: 0.5840 - val_loss: 1.9669 - val_accuracy: 0.7275
# Epoch 3/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9478 - accuracy: 0.6450 - val_loss: 1.9355 - val_accuracy: 0.8225
# Epoch 4/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9197 - accuracy: 0.6800 - val_loss: 1.9018 - val_accuracy: 0.7975
# Epoch 5/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8830 - accuracy: 0.7245 - val_loss: 1.8745 - val_accuracy: 0.7625
# Epoch 6/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.8504 - accuracy: 0.7435 - val_loss: 1.8425 - val_accuracy: 0.7775
# Epoch 7/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.8165 - accuracy: 0.7695 - val_loss: 1.8071 - val_accuracy: 0.7975
# Epoch 8/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7787 - accuracy: 0.7990 - val_loss: 1.7738 - val_accuracy: 0.8050
# Epoch 9/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7479 - accuracy: 0.8010 - val_loss: 1.7486 - val_accuracy: 0.7900
# Epoch 10/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7211 - accuracy: 0.7980 - val_loss: 1.7134 - val_accuracy: 0.8225
# Epoch 11/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6928 - accuracy: 0.8205 - val_loss: 1.6935 - val_accuracy: 0.7950
# Epoch 12/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6605 - accuracy: 0.8270 - val_loss: 1.6725 - val_accuracy: 0.7875
# Epoch 13/25
# 63/63 [==============================] - 1s 11ms/step - loss: 1.6338 - accuracy: 0.8440 - val_loss: 1.6320 - val_accuracy: 0.8400
# Epoch 14/25
# 63/63 [==============================] - 1s 11ms/step - loss: 1.6069 - accuracy: 0.8425 - val_loss: 1.6255 - val_accuracy: 0.7850
# Epoch 15/25
# 63/63 [==============================] - 1s 13ms/step - loss: 1.5852 - accuracy: 0.8480 - val_loss: 1.6102 - val_accuracy: 0.7800
# Epoch 16/25
# 63/63 [==============================] - 1s 10ms/step - loss: 1.5589 - accuracy: 0.8590 - val_loss: 1.5710 - val_accuracy: 0.8200
# Epoch 17/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5358 - accuracy: 0.8530 - val_loss: 1.5641 - val_accuracy: 0.7875
# Epoch 18/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5108 - accuracy: 0.8640 - val_loss: 1.5312 - val_accuracy: 0.8225
# Epoch 19/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4798 - accuracy: 0.8680 - val_loss: 1.4954 - val_accuracy: 0.8475
# Epoch 20/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4663 - accuracy: 0.8770 - val_loss: 1.5073 - val_accuracy: 0.8025
# Epoch 21/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4376 - accuracy: 0.8760 - val_loss: 1.5029 - val_accuracy: 0.7900
# Epoch 22/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4258 - accuracy: 0.8835 - val_loss: 1.4653 - val_accuracy: 0.8300
# Epoch 23/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.3979 - accuracy: 0.8815 - val_loss: 1.4387 - val_accuracy: 0.8500
# Epoch 24/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.3789 - accuracy: 0.8920 - val_loss: 1.4301 - val_accuracy: 0.8350
# Epoch 25/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.3679 - accuracy: 0.8920 - val_loss: 1.3988 - val_accuracy: 0.8675
# Epoch 1/25
# 63/63 [==============================] - 2s 12ms/step - loss: 2.0150 - accuracy: 0.5300 - val_loss: 1.9966 - val_accuracy: 0.5100
# Epoch 2/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9762 - accuracy: 0.6065 - val_loss: 1.9564 - val_accuracy: 0.7450
# Epoch 3/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.9425 - accuracy: 0.6555 - val_loss: 1.9253 - val_accuracy: 0.7575
# Epoch 4/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.9048 - accuracy: 0.6965 - val_loss: 1.8893 - val_accuracy: 0.8050
# Epoch 5/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.8735 - accuracy: 0.7275 - val_loss: 1.8549 - val_accuracy: 0.8075
# Epoch 6/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.8425 - accuracy: 0.7535 - val_loss: 1.8328 - val_accuracy: 0.7475
# Epoch 7/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.8095 - accuracy: 0.7655 - val_loss: 1.7895 - val_accuracy: 0.8325
# Epoch 8/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7741 - accuracy: 0.7890 - val_loss: 1.7610 - val_accuracy: 0.8050
# Epoch 9/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.7473 - accuracy: 0.7980 - val_loss: 1.7494 - val_accuracy: 0.7650
# Epoch 10/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.7120 - accuracy: 0.8195 - val_loss: 1.7134 - val_accuracy: 0.8000
# Epoch 11/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6867 - accuracy: 0.8100 - val_loss: 1.6809 - val_accuracy: 0.8200
# Epoch 12/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6630 - accuracy: 0.8310 - val_loss: 1.6514 - val_accuracy: 0.8275
# Epoch 13/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6326 - accuracy: 0.8385 - val_loss: 1.6228 - val_accuracy: 0.8625
# Epoch 14/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.6053 - accuracy: 0.8475 - val_loss: 1.5923 - val_accuracy: 0.8675
# Epoch 15/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5827 - accuracy: 0.8550 - val_loss: 1.5748 - val_accuracy: 0.8525
# Epoch 16/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5642 - accuracy: 0.8510 - val_loss: 1.5541 - val_accuracy: 0.8600
# Epoch 17/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.5326 - accuracy: 0.8685 - val_loss: 1.5269 - val_accuracy: 0.8650
# Epoch 18/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.5207 - accuracy: 0.8670 - val_loss: 1.5215 - val_accuracy: 0.8550
# Epoch 19/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.4883 - accuracy: 0.8815 - val_loss: 1.4874 - val_accuracy: 0.8675
# Epoch 20/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4837 - accuracy: 0.8795 - val_loss: 1.5246 - val_accuracy: 0.8250
# Epoch 21/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4564 - accuracy: 0.8905 - val_loss: 1.4866 - val_accuracy: 0.8575
# Epoch 22/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4443 - accuracy: 0.8870 - val_loss: 1.4673 - val_accuracy: 0.8650
# Epoch 23/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4308 - accuracy: 0.8825 - val_loss: 1.4556 - val_accuracy: 0.8625
# Epoch 24/25
# 63/63 [==============================] - 1s 9ms/step - loss: 1.4040 - accuracy: 0.8995 - val_loss: 1.4887 - val_accuracy: 0.8125
# Epoch 25/25
# 63/63 [==============================] - 1s 8ms/step - loss: 1.3946 - accuracy: 0.8945 - val_loss: 1.4163 - val_accuracy: 0.8850
# 0.6875

# %% [markdown]
# ## Activity 1b: Understanding our model's performance on field data

# %% [markdown]
# ### Exercise (Discussion)
# Discuss this with your instructor:
# * How did your model do? Did it perform quite as well?
# * Why do you think it did this way?
# * **Come up with a few hypotheses for what's different between our test data and our field data!**

# %% [markdown]
# ## Activity 1c: Error analysis
#
# ### Understanding where the model did not perform as well

# %% [markdown]
# ### Exercise (Coding)

# %% [markdown]
# Since our `field_data` comes from the field, it's possible that it's different from `train_data` and `test_data` in some important ways!
#
# Let's compare a few images. Below, please use a `for` loop and `plot_one_image(data, labels, index)` to print out a few images from the different datasets.
#
# **Do you notice any differences in the datasets?**

# %%
#YOUR CODE HERE
print('field data:\n') 
for i in range(6):
  plot_one_image(field_data, field_labels, i)
print('train data:\n') 
for j in range(6):
 plot_one_image(train_data, train_labels, i)
### END CODE
# Out:
# field data:
#
# Label: 1.0
# Label: 1.0
# Label: 0.0
# Label: 0.0
# Label: 0.0
# Label: 1.0
# train data:
#
# Label: 1.0
# Label: 1.0
# Label: 1.0
# Label: 1.0
# Label: 1.0
# Label: 1.0

# %% [markdown]
# ## Instructor-Led Discussion: What is happening in our field data?
#
# Discuss in your group and with your instructor:
#
# Why is our model performance suffering? What are reasons that field data could be "messier"?

# %% [markdown]
# # Milestone 2: Tools to improve your models

# %% [markdown]
# ## Activity 2a

# %% [markdown]
# ### Instructor-Led Discussion: Data Augmentation
#
# We want our model to handle a broader variety of input data. One way to do this is to **augment** our data: by intentionally making some alterations to our input data, we an train our model to handle a greater variety of outputs.

# %% [markdown]
# ### Exercise (Coding)

# %% [markdown]
# So, how do we augment our images in Python?
#
#
# We provide custom functions for augmenting a single image. Here's one example, to rotate a single image by 40 degrees. **Experiment with changing the degrees! How can you rotate left?**

# %%
image = train_data[0]
plot_one_image(image) 
new_image = rotate(image, rotate = 40)
plot_one_image(new_image)
# Out:
# Label:
# Label:

# %% [markdown]
# Here's some more image transformation options:
# * `rotate(image, rotate = 30)`
# * `scale(image, scale = 1.5)`
# * `shear(image, shear = 20)`
# * `flip_left_right(image, prob = 0.5)`
# * `flip_up_down(image, prob = 0.5)`
# * `remove_color(data, channel = 0)`
#
# Try it out below!

# %%
#YOUR CODE HERE
image = train_data[0]
plot_one_image(image) 
#new_image=scale(image, scale = 3)
#new_image=shear(image, shear = 20)
new_image=remove_color(image, channel = 0)
plot_one_image(new_image)
# Out:
# Label:
# Label:

# %% [markdown]
# Now, experiment with these options!
#
# **Share some of your cool augmentation strategies with the class! You can definitely use multiple augmentation techniques for each image!**

# %%
### YOUR CODE HERE

### END CODE

# %% [markdown]
# ## Activity 2b.

# %% [markdown]
# ### Exercise (Coding)

# %% [markdown]
# Now, let's create some augmented datasets of our own! We'll combine the augmented data with the original. Here's how you make an augmented dataset:

# %%
train_data_rotated_10 = rotate(train_data, rotate=10)

# %% [markdown]
# Please make some more augmented datasets below!

# %%
train_data_rotated_30 = rotate(train_data, rotate=10)
###YOUR CODE HERE to create more augmented datasets

image = train_data[20]
train_data_scaled_4=scale(train_data, scale = 4)
train_data_sheared=shear(train_data, shear = 31)
train_data_color_removed=remove_color(train_data, channel = 0)

# %% [markdown]
# Finally, to combine your original train data with your augmented data, you can use the `combine_data` function like this:
# ```
# all_data, all_labels = combine_data([data1, data2], [labels1, labels2])
# ```
#
# (You can include as many datasets as you like in the list. What should you use for the new labels?)
#
# Please create `all_data` and `all_labels` below:

# %%
#YOUR CODE HERE
all_data, all_labels = combine_data([train_data,train_data_scaled_4,train_data_sheared,train_data_color_removed], [train_labels,train_labels,train_labels,train_labels])
### END CODE

# %% [markdown]
# Once you've created your augmented data...
# 1. Train your CNN on `all_data`
# 2. Choose the best epoch based on the `test_data`!
# 3. Load your model up and score it on `field_data`.
#
# **Your challenge is to find a set of augmentations that improves your model's performance on the `field_data`! Share your augmentations and performances with the class! Try as many or as few augmentations as you want.**
#
# **Remember to record an average of 5 newly initialized CNNs. This is important because CNN weights will be initialized differently in each run!**

# %%
train_data, train_labels = get_train_data()
test_data, test_labels   = get_test_data()
field_data, field_labels   = get_field_data()

### YOUR CODE HERE
sum=0.0
for i in range(5):
  cnn = CNNClassifier(num_hidden_layers = 2)
  model_history_cnn = cnn.fit(all_data, all_labels, epochs = 25, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
  plot_acc(model_history_cnn)
  predictions=(cnn.predict(field_data)>0.5).astype('int32')
  accuracy=accuracy_score(field_labels,predictions)
  sum+=accuracy
print(sum/5)

### END CODE
# Out:
# Epoch 1/25
# 250/250 [==============================] - 3s 8ms/step - loss: 1.9863 - accuracy: 0.5328 - val_loss: 1.9383 - val_accuracy: 0.7925
# Epoch 2/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.9130 - accuracy: 0.6021 - val_loss: 1.8532 - val_accuracy: 0.7100
# Epoch 3/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.8419 - accuracy: 0.6538 - val_loss: 1.7687 - val_accuracy: 0.7700
# Epoch 4/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7735 - accuracy: 0.6837 - val_loss: 1.6895 - val_accuracy: 0.8075
# Epoch 5/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7105 - accuracy: 0.7097 - val_loss: 1.6187 - val_accuracy: 0.8100
# Epoch 6/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.6433 - accuracy: 0.7290 - val_loss: 1.5402 - val_accuracy: 0.8350
# Epoch 7/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.5788 - accuracy: 0.7545 - val_loss: 1.4816 - val_accuracy: 0.8375
# Epoch 8/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.5242 - accuracy: 0.7670 - val_loss: 1.4368 - val_accuracy: 0.8275
# Epoch 9/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4660 - accuracy: 0.7751 - val_loss: 1.3618 - val_accuracy: 0.8425
# Epoch 10/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4172 - accuracy: 0.7880 - val_loss: 1.3152 - val_accuracy: 0.8475
# Epoch 11/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3708 - accuracy: 0.7964 - val_loss: 1.2720 - val_accuracy: 0.8500
# Epoch 12/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3229 - accuracy: 0.8034 - val_loss: 1.2500 - val_accuracy: 0.8375
# Epoch 13/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2749 - accuracy: 0.8191 - val_loss: 1.1987 - val_accuracy: 0.8475
# Epoch 14/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2377 - accuracy: 0.8226 - val_loss: 1.1530 - val_accuracy: 0.8700
# Epoch 15/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1984 - accuracy: 0.8313 - val_loss: 1.2013 - val_accuracy: 0.8150
# Epoch 16/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1701 - accuracy: 0.8289 - val_loss: 1.1605 - val_accuracy: 0.8275
# Epoch 17/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1358 - accuracy: 0.8396 - val_loss: 1.1016 - val_accuracy: 0.8325
# Epoch 18/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1033 - accuracy: 0.8438 - val_loss: 1.1157 - val_accuracy: 0.8200
# Epoch 19/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0744 - accuracy: 0.8494 - val_loss: 1.0888 - val_accuracy: 0.8175
# Epoch 20/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0493 - accuracy: 0.8518 - val_loss: 1.0881 - val_accuracy: 0.8100
# Epoch 21/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0229 - accuracy: 0.8541 - val_loss: 1.0643 - val_accuracy: 0.8150
# Epoch 22/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9977 - accuracy: 0.8637 - val_loss: 1.0030 - val_accuracy: 0.8400
# Epoch 23/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9763 - accuracy: 0.8614 - val_loss: 1.0634 - val_accuracy: 0.7975
# Epoch 24/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9531 - accuracy: 0.8645 - val_loss: 1.0951 - val_accuracy: 0.7850
# Epoch 25/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9306 - accuracy: 0.8645 - val_loss: 1.0354 - val_accuracy: 0.8000
# Epoch 1/25
# 250/250 [==============================] - 3s 8ms/step - loss: 1.9835 - accuracy: 0.5399 - val_loss: 1.9426 - val_accuracy: 0.5400
# Epoch 2/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.9141 - accuracy: 0.6058 - val_loss: 1.8690 - val_accuracy: 0.6675
# Epoch 3/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.8420 - accuracy: 0.6505 - val_loss: 1.7915 - val_accuracy: 0.7425
# Epoch 4/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7740 - accuracy: 0.6814 - val_loss: 1.7202 - val_accuracy: 0.7725
# Epoch 5/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7087 - accuracy: 0.7023 - val_loss: 1.6426 - val_accuracy: 0.8275
# Epoch 6/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.6469 - accuracy: 0.7199 - val_loss: 1.5709 - val_accuracy: 0.8300
# Epoch 7/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.5918 - accuracy: 0.7236 - val_loss: 1.5135 - val_accuracy: 0.8350
# Epoch 8/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.5345 - accuracy: 0.7418 - val_loss: 1.4454 - val_accuracy: 0.8350
# Epoch 9/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4788 - accuracy: 0.7565 - val_loss: 1.3885 - val_accuracy: 0.8475
# Epoch 10/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4236 - accuracy: 0.7678 - val_loss: 1.3383 - val_accuracy: 0.8375
# Epoch 11/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3769 - accuracy: 0.7772 - val_loss: 1.2841 - val_accuracy: 0.8450
# Epoch 12/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3272 - accuracy: 0.7870 - val_loss: 1.2365 - val_accuracy: 0.8500
# Epoch 13/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2811 - accuracy: 0.7947 - val_loss: 1.2091 - val_accuracy: 0.8375
# Epoch 14/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2399 - accuracy: 0.8027 - val_loss: 1.1618 - val_accuracy: 0.8425
# Epoch 15/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1968 - accuracy: 0.8075 - val_loss: 1.1183 - val_accuracy: 0.8600
# Epoch 16/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1584 - accuracy: 0.8184 - val_loss: 1.1065 - val_accuracy: 0.8400
# Epoch 17/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1229 - accuracy: 0.8267 - val_loss: 1.0972 - val_accuracy: 0.8225
# Epoch 18/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0941 - accuracy: 0.8255 - val_loss: 1.0461 - val_accuracy: 0.8425
# Epoch 19/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0620 - accuracy: 0.8325 - val_loss: 1.0393 - val_accuracy: 0.8325
# Epoch 20/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0269 - accuracy: 0.8393 - val_loss: 1.0469 - val_accuracy: 0.7950
# Epoch 21/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0025 - accuracy: 0.8443 - val_loss: 0.9562 - val_accuracy: 0.8550
# Epoch 22/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9790 - accuracy: 0.8496 - val_loss: 0.9984 - val_accuracy: 0.7950
# Epoch 23/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9547 - accuracy: 0.8485 - val_loss: 0.9670 - val_accuracy: 0.8125
# Epoch 24/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9245 - accuracy: 0.8577 - val_loss: 0.9430 - val_accuracy: 0.8200
# Epoch 25/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9001 - accuracy: 0.8589 - val_loss: 0.9629 - val_accuracy: 0.7925
# Epoch 1/25
# 250/250 [==============================] - 3s 8ms/step - loss: 1.9856 - accuracy: 0.5489 - val_loss: 1.9454 - val_accuracy: 0.6050
# Epoch 2/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.9150 - accuracy: 0.5881 - val_loss: 1.8687 - val_accuracy: 0.6875
# Epoch 3/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.8446 - accuracy: 0.6376 - val_loss: 1.7907 - val_accuracy: 0.7625
# Epoch 4/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7772 - accuracy: 0.6634 - val_loss: 1.7121 - val_accuracy: 0.7750
# Epoch 5/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7121 - accuracy: 0.6945 - val_loss: 1.6428 - val_accuracy: 0.7825
# Epoch 6/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.6432 - accuracy: 0.7253 - val_loss: 1.5783 - val_accuracy: 0.7750
# Epoch 7/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.5802 - accuracy: 0.7368 - val_loss: 1.5069 - val_accuracy: 0.7925
# Epoch 8/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.5266 - accuracy: 0.7492 - val_loss: 1.4413 - val_accuracy: 0.8225
# Epoch 9/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4699 - accuracy: 0.7615 - val_loss: 1.3865 - val_accuracy: 0.8350
# Epoch 10/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4161 - accuracy: 0.7760 - val_loss: 1.3316 - val_accuracy: 0.8300
# Epoch 11/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3656 - accuracy: 0.7845 - val_loss: 1.2882 - val_accuracy: 0.8375
# Epoch 12/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3155 - accuracy: 0.7931 - val_loss: 1.2304 - val_accuracy: 0.8350
# Epoch 13/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2734 - accuracy: 0.8012 - val_loss: 1.2063 - val_accuracy: 0.8300
# Epoch 14/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2264 - accuracy: 0.8106 - val_loss: 1.1778 - val_accuracy: 0.8300
# Epoch 15/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1889 - accuracy: 0.8106 - val_loss: 1.1527 - val_accuracy: 0.8250
# Epoch 16/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1528 - accuracy: 0.8219 - val_loss: 1.0909 - val_accuracy: 0.8475
# Epoch 17/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1196 - accuracy: 0.8239 - val_loss: 1.1202 - val_accuracy: 0.8150
# Epoch 18/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0856 - accuracy: 0.8309 - val_loss: 1.0325 - val_accuracy: 0.8550
# Epoch 19/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0547 - accuracy: 0.8404 - val_loss: 1.0546 - val_accuracy: 0.8250
# Epoch 20/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0243 - accuracy: 0.8416 - val_loss: 0.9864 - val_accuracy: 0.8500
# Epoch 21/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0004 - accuracy: 0.8414 - val_loss: 1.0159 - val_accuracy: 0.8225
# Epoch 22/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9737 - accuracy: 0.8469 - val_loss: 0.9708 - val_accuracy: 0.8350
# Epoch 23/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9458 - accuracy: 0.8569 - val_loss: 1.0120 - val_accuracy: 0.8125
# Epoch 24/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9201 - accuracy: 0.8591 - val_loss: 1.0569 - val_accuracy: 0.7825
# Epoch 25/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.8991 - accuracy: 0.8634 - val_loss: 0.9902 - val_accuracy: 0.8050
# Epoch 1/25
# 250/250 [==============================] - 3s 8ms/step - loss: 1.9985 - accuracy: 0.5216 - val_loss: 1.9517 - val_accuracy: 0.7125
# Epoch 2/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.9204 - accuracy: 0.5870 - val_loss: 1.8701 - val_accuracy: 0.7400
# Epoch 3/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.8484 - accuracy: 0.6270 - val_loss: 1.7904 - val_accuracy: 0.7925
# Epoch 4/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7808 - accuracy: 0.6585 - val_loss: 1.7146 - val_accuracy: 0.7625
# Epoch 5/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7118 - accuracy: 0.6835 - val_loss: 1.6374 - val_accuracy: 0.8325
# Epoch 6/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.6469 - accuracy: 0.7089 - val_loss: 1.5694 - val_accuracy: 0.8700
# Epoch 7/25
# 250/250 [==============================] - 2s 8ms/step - loss: 1.5839 - accuracy: 0.7272 - val_loss: 1.5028 - val_accuracy: 0.8700
# Epoch 8/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.5277 - accuracy: 0.7448 - val_loss: 1.4379 - val_accuracy: 0.8675
# Epoch 9/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4679 - accuracy: 0.7552 - val_loss: 1.3804 - val_accuracy: 0.8700
# Epoch 10/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4149 - accuracy: 0.7676 - val_loss: 1.3159 - val_accuracy: 0.8750
# Epoch 11/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3585 - accuracy: 0.7810 - val_loss: 1.2818 - val_accuracy: 0.8650
# Epoch 12/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3103 - accuracy: 0.7886 - val_loss: 1.2225 - val_accuracy: 0.8675
# Epoch 13/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2654 - accuracy: 0.7943 - val_loss: 1.1709 - val_accuracy: 0.8700
# Epoch 14/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2239 - accuracy: 0.8025 - val_loss: 1.1335 - val_accuracy: 0.8725
# Epoch 15/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1855 - accuracy: 0.8073 - val_loss: 1.1474 - val_accuracy: 0.8300
# Epoch 16/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1465 - accuracy: 0.8175 - val_loss: 1.0593 - val_accuracy: 0.8725
# Epoch 17/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1146 - accuracy: 0.8195 - val_loss: 1.0894 - val_accuracy: 0.8225
# Epoch 18/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0786 - accuracy: 0.8253 - val_loss: 1.0486 - val_accuracy: 0.8425
# Epoch 19/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0422 - accuracy: 0.8301 - val_loss: 1.0290 - val_accuracy: 0.8325
# Epoch 20/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0162 - accuracy: 0.8370 - val_loss: 1.0599 - val_accuracy: 0.7875
# Epoch 21/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9892 - accuracy: 0.8424 - val_loss: 0.9760 - val_accuracy: 0.8450
# Epoch 22/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9608 - accuracy: 0.8462 - val_loss: 1.0294 - val_accuracy: 0.7850
# Epoch 23/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9414 - accuracy: 0.8486 - val_loss: 1.0056 - val_accuracy: 0.7875
# Epoch 24/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9170 - accuracy: 0.8522 - val_loss: 0.9043 - val_accuracy: 0.8550
# Epoch 25/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.8886 - accuracy: 0.8602 - val_loss: 0.9790 - val_accuracy: 0.7875
# Epoch 1/25
# 250/250 [==============================] - 3s 8ms/step - loss: 2.0047 - accuracy: 0.5347 - val_loss: 1.9630 - val_accuracy: 0.7400
# Epoch 2/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.9307 - accuracy: 0.5957 - val_loss: 1.8900 - val_accuracy: 0.5975
# Epoch 3/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.8608 - accuracy: 0.6277 - val_loss: 1.8091 - val_accuracy: 0.7925
# Epoch 4/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7912 - accuracy: 0.6699 - val_loss: 1.7372 - val_accuracy: 0.7850
# Epoch 5/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.7224 - accuracy: 0.6966 - val_loss: 1.6588 - val_accuracy: 0.8100
# Epoch 6/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.6638 - accuracy: 0.6967 - val_loss: 1.5963 - val_accuracy: 0.8100
# Epoch 7/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.6037 - accuracy: 0.7210 - val_loss: 1.5289 - val_accuracy: 0.8325
# Epoch 8/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.5473 - accuracy: 0.7300 - val_loss: 1.4650 - val_accuracy: 0.8125
# Epoch 9/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4847 - accuracy: 0.7480 - val_loss: 1.4041 - val_accuracy: 0.8225
# Epoch 10/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.4333 - accuracy: 0.7591 - val_loss: 1.3461 - val_accuracy: 0.8200
# Epoch 11/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3797 - accuracy: 0.7605 - val_loss: 1.2976 - val_accuracy: 0.8350
# Epoch 12/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.3347 - accuracy: 0.7719 - val_loss: 1.2534 - val_accuracy: 0.8375
# Epoch 13/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2871 - accuracy: 0.7825 - val_loss: 1.2200 - val_accuracy: 0.8325
# Epoch 14/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2391 - accuracy: 0.7940 - val_loss: 1.1644 - val_accuracy: 0.8350
# Epoch 15/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.2006 - accuracy: 0.7962 - val_loss: 1.1196 - val_accuracy: 0.8475
# Epoch 16/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1614 - accuracy: 0.8034 - val_loss: 1.0857 - val_accuracy: 0.8475
# Epoch 17/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.1261 - accuracy: 0.8141 - val_loss: 1.0726 - val_accuracy: 0.8325
# Epoch 18/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0882 - accuracy: 0.8176 - val_loss: 1.0794 - val_accuracy: 0.8075
# Epoch 19/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0558 - accuracy: 0.8192 - val_loss: 1.0036 - val_accuracy: 0.8425
# Epoch 20/25
# 250/250 [==============================] - 2s 7ms/step - loss: 1.0215 - accuracy: 0.8255 - val_loss: 1.0035 - val_accuracy: 0.8175
# Epoch 21/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9970 - accuracy: 0.8340 - val_loss: 0.9630 - val_accuracy: 0.8350
# Epoch 22/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9638 - accuracy: 0.8405 - val_loss: 0.9275 - val_accuracy: 0.8575
# Epoch 23/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9431 - accuracy: 0.8399 - val_loss: 0.9544 - val_accuracy: 0.8125
# Epoch 24/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.9206 - accuracy: 0.8504 - val_loss: 0.8955 - val_accuracy: 0.8475
# Epoch 25/25
# 250/250 [==============================] - 2s 7ms/step - loss: 0.8982 - accuracy: 0.8481 - val_loss: 0.9586 - val_accuracy: 0.8000
# 0.7815

# %% [markdown]
# ## Instructor-Led Discussion: Why does data augmentation improve average performance?

# %% [markdown]
# ![](https://storage.googleapis.com/kaggle-competitions/kaggle/10338/logos/header.png)

# %% [markdown]
# ##Congratulations on completing your model!
#
# By augmenting your data, you've (hopefully) gotten your models working better, even on messy field data!
#
# As a further challenge, you can return to any point in the challenge and try to improve:
# - Try looking at the CNN code in the hidden cell at the top. Can you change the parameters to reduce overfitting?
# - Try out different classifiers from Scikit-learn with augmented data.
# - Create new combinations of augmentations for your data.
# - Whatever ideas you come up with!
